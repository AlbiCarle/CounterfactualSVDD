# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import ranksums

# %%
# factuals and counterfactuals derived from classical TC-SVDD
factuals1=pd.read_csv("factuals_canonicalSVDD.txt",sep="\t") 
counterfactuals1=pd.read_csv("counterfactuals_canonicalSVDD.txt",sep="\t")
factuals1=factuals1[(counterfactuals1["sBP"].values!=0)] #factuals that have admissible counterfactuals
counterfactuals1=counterfactuals1[(counterfactuals1["sBP"].values!=0)]

# factuals and counterfactuals derived from TC-SVDD with FNR-REDUCTION
factuals2=pd.read_csv("factuals_FNR_reduction.txt",sep="\t") 
counterfactuals2=pd.read_csv("counterfactuals_FNR_reduction.txt",sep="\t")
factuals2=factuals2[(counterfactuals2["sBP"].values!=0)] #factuals that have admissible counterfactuals
counterfactuals2=counterfactuals2[(counterfactuals2["sBP"].values!=0)]

# find common factuals
factuals1['index1'] = factuals1.index
factuals2['index2'] = factuals2.index
factuals_intersect=pd.merge(factuals1,factuals2,on=['Sex','Age','sBP','BMI','FBS','LDL','HDL','TG','Total Cholesterol','HTN','Class'])

# find counterfactuals derived from common factuals
counterfactuals1=counterfactuals1.loc[factuals_intersect['index1'],:]#CLASSIC
counterfactuals1=counter_classic.reset_index()
counterfactuals2=counterfactuals2.loc[factuals_intersect['index2'],:] #FNR RED
counterfactuals2=counter_FNRRed.reset_index()

# %%
#consider four different subgroups: F_HTN, F_noHTN, M_HTN, M_noHTN
factuals_f_HTN=factuals_intersect.loc[(factuals_intersect['Sex'] ==0) & (factuals_intersect['HTN'] ==1)]
counter1_f_HTN=counterfactuals1.loc[(factuals_intersect['Sex'] ==0) & (factuals_intersect['HTN'] ==1)]
counter2_f_HTN=counterfactuals2.loc[(factuals_intersect['Sex'] ==0) & (factuals_intersect['HTN'] ==1)]

factuals_f_noHTN=factuals_intersect.loc[(factuals_intersect['Sex'] ==0) & (factuals_intersect['HTN'] ==0)]
counter1_f_noHTN=counterfactuals1.loc[(factuals_intersect['Sex'] ==0) & (factuals_intersect['HTN'] ==0)]
counter2_f_noHTN=counterfactuals2.loc[(factuals_intersect['Sex'] ==0) & (factuals_intersect['HTN'] ==0)]

factuals_m_HTN=factuals_intersect.loc[(factuals_intersect['Sex'] ==1) & (factuals_intersect['HTN'] ==1)]
counter1_m_HTN=counterfactuals1.loc[(factuals_intersect['Sex'] ==1) & (factuals_intersect['HTN'] ==1)]
counter2_m_HTN=counterfactuals2.loc[(factuals_intersect['Sex'] ==1) & (factuals_intersect['HTN'] ==1)]

factuals_m_noHTN=factuals_intersect.loc[(factuals_intersect['Sex'] ==1) & (factuals_intersect['HTN'] ==0)]
counter1_m_noHTN=counterfactuals1.loc[(factuals_intersect['Sex'] ==1) & (factuals_intersect['HTN'] ==0)]
counter2_m_noHTN=counterfactuals2.loc[(factuals_intersect['Sex'] ==1) & (factuals_intersect['HTN'] ==0)]

# %%
#f HTN
print(ranksums(counter1_f_HTN['BMI'],counter2_f_HTN['BMI']))
print(ranksums(counter1_f_HTN['FBS'],counter2_f_HTN['FBS']))
print(ranksums(counter1_f_HTN['sBP'],counter2_f_HTN['sBP']))
print(ranksums(counter1_f_HTN['HDL'],counter2_f_HTN['HDL']))
print(ranksums(counter1_f_HTN['LDL'],counter2_f_HTN['LDL']))
print(ranksums(counter1_f_HTN['TG'],counter2_f_HTN['TG']))
print(ranksums(counter1_f_HTN['Total Cholesterol'],counter2_f_HTN['Total Cholesterol']))

#m no HTN
print(ranksums(counter1_f_noHTN['BMI'],counter2_f_noHTN['BMI']))
print(ranksums(counter1_f_noHTN['FBS'],counter2_f_noHTN['FBS']))
print(ranksums(counter1_f_noHTN['sBP'],counter2_f_noHTN['sBP']))
print(ranksums(counter1_f_noHTN['HDL'],counter2_f_noHTN['HDL']))
print(ranksums(counter1_f_noHTN['LDL'],counter2_f_noHTN['LDL']))
print(ranksums(counter1_f_noHTN['TG'],counter2_f_noHTN['TG']))
print(ranksums(counter1_f_noHTN['Total Cholesterol'],counter2_f_noHTN['Total Cholesterol']))

#m HTN
print(ranksums(counter1_m_HTN['BMI'],counter2_m_HTN['BMI']))
print(ranksums(counter1_m_HTN['FBS'],counter2_m_HTN['FBS']))
print(ranksums(counter1_m_HTN['sBP'],counter2_m_HTN['sBP']))
print(ranksums(counter1_m_HTN['HDL'],counter2_m_HTN['HDL']))
print(ranksums(counter1_m_HTN['LDL'],counter2_m_HTN['LDL']))
print(ranksums(counter1_m_HTN['TG'],counter2_m_HTN['TG']))
print(ranksums(counter1_m_HTN['Total Cholesterol'],counter2_m_HTN['Total Cholesterol']))

#m no HTN
print(ranksums(counter1_m_noHTN['BMI'],counter2_m_noHTN['BMI']))
print(ranksums(counter1_m_noHTN['FBS'],counter2_m_noHTN['FBS']))
print(ranksums(counter1_m_noHTN['sBP'],counter2_m_noHTN['sBP']))
print(ranksums(counter1_m_noHTN['HDL'],counter2_m_noHTN['HDL']))
print(ranksums(counter1_m_noHTN['LDL'],counter2_m_noHTN['LDL']))
print(ranksums(counter1_m_noHTN['TG'],counter2_m_noHTN['TG']))
print(ranksums(counter1_m_noHTN['Total Cholesterol'],counter2_m_noHTN['Total Cholesterol']))

# %%
#F_HTN
diff1_f_HTN=counter1_f_HTN-factuals_f_HTN
diff1_f_HTN['ind']=counter1_f_HTN.index
diff2_f_HTN=counter2_f_HTN-factuals_f_HTN
diff2_f_HTN['ind']=counter2_f_HTN.index
#drop useless columns
diff1_f_HTN=diff1_f_HTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)
diff2_f_HTN=diff2_f_HTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)
#create dataframe for F_HTN
diff_f_HTN=pd.merge(diff1_f_HTN,diff2_f_HTN,on=['ind'])
column_names = ["sBP_x", "sBP_y", "FBS_x","FBS_y","BMI_x","BMI_y","TG_x","TG_y","HDL_x","HDL_y",'LDL_x','LDL_y','Total Cholesterol_x','Total Cholesterol_y'] 
diff_f_HTN = diff_f_HTN.reindex(columns=column_names)
diff_f_HTN.describe()


#F_noHTN
diff1_f_noHTN=counter1_f_noHTN-factuals_f_noHTN
diff1_f_noHTN['ind']=counter1_f_noHTN.index
diff2_f_noHTN=counter2_f_noHTN-factuals_f_noHTN
diff2_f_noHTN['ind']=counter2_f_noHTN.index
#drop useless columns
diff1_f_noHTN=diff1_f_noHTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)
diff2_f_noHTN=diff2_f_noHTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)
#create dataframe for F_noHTN
diff_f_noHTN=pd.merge(diff1_f_noHTN,diff2_f_noHTN,on=['ind'])
column_names = ["sBP_x", "sBP_y", "FBS_x","FBS_y","BMI_x","BMI_y","TG_x","TG_y","HDL_x","HDL_y",'LDL_x','LDL_y','Total Cholesterol_x','Total Cholesterol_y'] 
diff_f_noHTN = diff_f_noHTN.reindex(columns=column_names)
diff_f_noHTN.describe()


#M_HTN
diff1_m_HTN=counter1_m_HTN-factuals_m_HTN
diff1_m_HTN['ind']=counter1_m_HTN.index
diff2_m_HTN=counter2_m_HTN-factuals_m_HTN
diff2_m_HTN['ind']=counter2_m_HTN.index
#drop useless columns
diff1_m_HTN=diff1_m_HTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)
diff2_m_HTN=diff2_m_HTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)

#create dataframe for m_HTN
diff_m_HTN=pd.merge(diff1_m_HTN,diff2_m_HTN,on=['ind'])
column_names = ["sBP_x", "sBP_y", "FBS_x","FBS_y","BMI_x","BMI_y","TG_x","TG_y","HDL_x","HDL_y",'LDL_x','LDL_y','Total Cholesterol_x','Total Cholesterol_y'] 
diff_m_HTN = diff_m_HTN.reindex(columns=column_names)
diff_m_HTN.describe()

#M_noHTN
diff1_m_noHTN=counter1_m_noHTN-factuals_m_noHTN
diff1_m_noHTN['ind']=counter1_m_noHTN.index
diff2_m_noHTN=counter2_m_noHTN-factuals_m_noHTN
diff2_m_noHTN['ind']=counter2_m_noHTN.index
#drop useless columns
diff1_m_noHTN=diff1_m_noHTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)
diff2_m_noHTN=diff2_m_noHTN.drop(['Class','Sex','index','index1','index2','Age','HTN'],axis=1)
#create dataframe for m_noHTN
diff_m_noHTN=pd.merge(diff1_m_noHTN,diff2_m_noHTN,on=['ind'])
column_names = ["sBP_x", "sBP_y", "FBS_x","FBS_y","BMI_x","BMI_y","TG_x","TG_y","HDL_x","HDL_y",'LDL_x','LDL_y','Total Cholesterol_x','Total Cholesterol_y'] 
diff_m_noHTN = diff_m_noHTN.reindex(columns=column_names)
diff_m_noHTN.describe()

# %%
#Boxplots Canonical TC-SVDD vs TC-SVDD_RED for FBS, sBP and BMI

# f HTN
diff1_f_HTN['group']='F_HTN'
diff1_f_HTN['SVDD type']='TC-SVDD'
print(diff1_f_HTN)
diff1_f_HTN=diff1_f_HTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)
diff2_f_HTN['group']='F_HTN'
diff2_f_HTN['SVDD type']='TC-SVDD_red'
diff2_f_HTN=diff2_f_HTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)
#f no HTN
diff1_f_noHTN['group']='F_noHTN'
diff1_f_noHTN['SVDD type']='TC-SVDD'
diff1_f_noHTN=diff1_f_noHTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)
diff2_f_noHTN['group']='F_noHTN'
diff2_f_noHTN['SVDD type']='TC-SVDD_red'
diff2_f_noHTN=diff2_f_noHTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)
# m HTN
diff1_m_HTN['group']='M_HTN'
diff1_m_HTN['SVDD type']='TC-SVDD'
diff1_m_HTN=diff1_m_HTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)
diff2_m_HTN['group']='M_HTN'
diff2_m_HTN['SVDD type']='TC-SVDD_red'
diff2_m_HTN=diff2_m_HTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)
# m no HTN
diff1_m_noHTN['group']='M_noHTN'
diff1_m_noHTN['SVDD type']='TC-SVDD'
diff1_m_noHTN=diff1_m_noHTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)
diff2_m_noHTN['group']='M_noHTN'
diff2_m_noHTN['SVDD type']='TC-SVDD_red'
diff2_m_noHTN=diff2_m_noHTN.drop(['TG','LDL','HDL','Total Cholesterol'],axis=1)

data=pd.concat([diff1f_HTN,diff2f_HTN,diff1f_noHTN,diff2f_noHTN,diff1m_HTN,diff2m_HTN,diff1m_noHTN,diff2m_noHTN])


fig,ax=plt.subplots(3,1,figsize=(10, 18),sharex=True)
sns.boxplot(ax=ax[0],x="group", y="FBS", data=data, hue='SVDD', showfliers = False)
ax[0].set_ylabel('FBS [mmol/L]')
ax[0].legend(loc='upper right', prop={'size': 12})#, bbox_to_anchor=(1, 0.5),
ax[0].set(xlabel=None)
ax[0].set_ylim([-3.8, +3.8])
ax[0].axhline(0, ls='--', linewidth=0.6,color='gray')

sns.boxplot(ax=ax[1],x="group", y="sBP", data=data, hue='SVDD', showfliers = False)
ax[1].set_ylim([-37, +37])
ax[1].set_ylabel('sBP [mmHg]')
ax[1].set(xlabel=None)
y, h, col = data['sBP'].median() + 30, 0.2, 'k'
ax[1].axhline(0, ls='--', linewidth=0.6,color='gray')
ax[1].get_legend().remove()

sns.boxplot(ax=ax[2],x="group", y="BMI", data=data, hue='SVDD', showfliers = False)
ax[2].set_ylabel('BMI [kg/m^2]')
ax[2].set(xlabel=None)
ax[2].set_ylim([-22, +22])
ax[2].axhline(0, ls='--', linewidth=0.6,color='gray')
ax[2].get_legend().remove()

plt.savefig("Boxplot_nored_VS_FNRred.tif", dpi=320,bbox_inches='tight')
